# %% [markdown]
# <a href="https://colab.research.google.com/github/youssef88ab/Bank-Managment-System/blob/main/td7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Création d’un dataframe**

# %%
import pandas as pd

rows = [ {'col1' : 0.5 , 'col2' : 'schtromuph'} , {'col1' : 0.6 , 'col 2 ' : 'schtroumphette' } ]
pd.DataFrame(rows)

# %%
import os
os.getcwd()

# %%
df = pd.read_csv("data/data1.csv" , sep=";")
